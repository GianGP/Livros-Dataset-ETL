# %%
import pandas as pd
import numpy as np
import copy
import math

# %% [markdown]
# # Importação dos csv

# %%
autores = pd.read_csv('./datasets/authors.csv')
categorias = pd.read_csv('./datasets/categories.csv')
formatos = pd.read_csv('./datasets/formats.csv')
ds = pd.read_csv('./datasets/dataset.csv')

aux = {'authors': autores,
       'categories': categorias,
       'format': formatos}

# %% [markdown]
# # Definição das Funções

# %%
# Função para transformar em listas as strings que representam listas dentro do dataset
def clean_alt_list(list_):
    list_ = list_.replace(', ', '","')
    list_ = list_.replace('[', '["')
    list_ = list_.replace(']', '"]')
    return list_

# %%
# Função para cruzar os dados e gerar um dataset unificado
def join_dfs(df_main_id_column, df_aux, df_main):
    
    # Obtém nome da coluna de identificação e o nome da coluna de descrição
    # das tabelas auxiliares à dataset
    id_column = df_aux.columns[0]
    name_column = df_aux.columns[1]
    
    # Gera um dicionário a ser utilizado para unir as informações dos dfs
    dict_aux = df_aux.set_index(id_column)[name_column].to_dict()
    
    if name_column not in df_main.columns:   
        
        # Localiza a posição da coluna do dataset referente ao id da auxiliar
        # e cria uma nova coluna na posição seguinte
        ix = df_main.columns.get_loc(df_main_id_column) + 1
        df.insert(ix, name_column, '')
        
        # Se a coluna que referencia a tabela auxiliar é uma string que representa lista
        # ela será tratada para virar uma lista
        if df[df_main_id_column].dtype == 'object':
            df[df_main_id_column] = df[df_main_id_column].apply(clean_alt_list)
            df[df_main_id_column] = df[df_main_id_column].apply(eval)
    
    # Se a coluna que referencia a tabela auxiliar é uma lista, as descrições 
    # serão unidas em uma string e adicionadas a nova coluna
    if df[df_main_id_column].dtype == 'object':
        df[name_column] = ['; '.join([str(dict_aux[int(j)]) for j in i if j != '']) for i in df[df_main_id_column]]
    
    # Caso contrátio os valores serão inseridos diretamente
    else:
        df[name_column] = [(dict_aux[i] if not math.isnan(i) else '') for i in df[df_main_id_column]]

# %%
# Função para transformar as colunas com listas em colunas com valores únicos (1D)
def to_1D(series):
    return pd.Series([x for _list in series for x in _list])

# %% [markdown]
# # Join information

# %%
# Cria-se uma cópia da dataset e une as informações das tabelas auxiliares a ela
df = copy.deepcopy(ds)
for aux_id_name, aux_df in aux.items():
    join_dfs(aux_id_name, aux_df, df)

# %% [markdown]
# # Questões

# %% [markdown]
# ## Transformações

# %%
# Função para agrupar os df e ordená-los a partir da sua contagem
def group_and_sort(id_name, df_aux, df_main):
    id_column = df_aux.columns[0]
    name_column = df_aux.columns[1]

    df_group = pd.DataFrame({id_column: to_1D(df_main[id_name]), 'contagem': 1})
    df_group[id_column] = pd.to_numeric(df_group[id_column])
    df_group = pd.merge(df_group, df_aux)[[name_column, 'contagem']]
    df_group = df_group.groupby(name_column, as_index=False).count()
    df_group = df_group.sort_values(name_column)
    
    df_sort = df_group.sort_values('contagem', ascending=False)
    return df_group, df_sort

# %%
# Transformações Questão 2
df.insert(2, 'author_quantity', 0)
df['author_quantity'] = df.apply(lambda row: len(row['authors']), axis=1)

# %%
# Transformações Questão 3
_, ranked_authors = group_and_sort('authors', autores, df)
ranked_authors = ranked_authors.head()

# %%
# Transformações Questão 4 e Questão 5
total_category, ranked_category = group_and_sort('categories', categorias, df)
ranked_category = ranked_category.head()

# %%
# Transformações Questão 6:
_ = df[['format_name', 'title']].groupby('format_name', as_index=False).count().sort_values('title', ascending=False)
most_used_format, quantity_format = _.head(1).iloc[0]

# %%
# Transformações Questão 7:
ranked_bestseller = df[['title', 'bestsellers-rank']].sort_values('bestsellers-rank').head(10)

# %%
# Transformações Questão 8:
ranked_rating = df[['title', 'rating-avg']].sort_values('rating-avg', ascending=False).head(10)

# %%
# Transformações Questão 9:
best_ratings = df[df['rating-avg'] > 3.5].title.count()

# %%
# Transformações Questão 10:
books_new_decade = df[df['publication-date'] > '2020-01-01'].title.count()

# %% [markdown]
# ## Soluções

# %%
# Questão 1:
print('Há {} livros no dataset'.format(df.title.count()))
# Out:
# Há 20216 livros no dataset

# %%
# Questão 2:
print('Há {} livros com apenas 1 autor'.format(df[df['author_quantity'] == 1].title.count()))
# Out:
# Há 15341 livros com apenas 1 autor

# %%
# Questão 3:
print('Top 5 autores com maiores quantidades de livros:\n')
for ix, row in enumerate(ranked_authors.values):
    print('{}° autor: {} com {} livros'.format(ix+1, row[0], row[1]))
# Out:
# Top 5 autores com maiores quantidades de livros:
#
# 1° autor: Weezag com 258 livros
# 2° autor: Rand McNally com 212 livros
# 3° autor: William Shakespeare com 117 livros
# 4° autor: Matthew Preston com 83 livros
# 5° autor: Kevin Lee com 83 livros

# %%
# Questão 4:
print('Quantidade de livros por categoria:\n')
for row in total_category.values:
    print('Categoria: {:75} Livros: {}'.format(row[0], row[1]))
# Out:
# Quantidade de livros por categoria:
#
# Categoria: 20th Century & Contemporary Classical Music                                 Livros: 4
# Categoria: 20th Century History: C 1900  To C 2000                                     Livros: 92
# Categoria: 21st Century History: From C 2000 -                                         Livros: 19
# Categoria: ABC                                                                         Livros: 2
# Categoria: Abnormal Psychology                                                         Livros: 17
# Categoria: Accident & Emergency Medicine                                               Livros: 1
# Categoria: Accounting                                                                  Livros: 4
# Categoria: Acoustic & Sound Engineering                                                Livros: 9
# Categoria: Acquisitions & Collection Development                                       Livros: 2
# Categoria: Acting Techniques                                                           Livros: 427
# Categoria: Active Outdoor Pursuits                                                     Livros: 2
# Categoria: Activity Books                                                              Livros: 12
# Categoria: Addiction & Therapy                                                         Livros: 1
# Categoria: Adoption                                                                    Livros: 1
# Categoria: Adoption & Fostering                                                        Livros: 1
# Categoria: Adult & Contemporary Romance                                                Livros: 4
# Categoria: Adult Education, Continuous Learning                                        Livros: 96
# Categoria: Adult Literacy Guides & Handbooks                                           Livros: 92
# Categoria: Adventure Books                                                             Livros: 28
# Categoria: Adventure Books for Kids                                                    Livros: 1
# Categoria: Adventure Holidays                                                          Livros: 1
# Categoria: Advertising                                                                 Livros: 7
# Categoria: Advertising & Society                                                       Livros: 3
# Categoria: Advertising Industry                                                        Livros: 4
# Categoria: Advice On Careers & Achieving Success                                       Livros: 109
# Categoria: Advice On Education                                                         Livros: 12
# Categoria: Advice On Parenting                                                         Livros: 37
# Categoria: Aerial Photography                                                          Livros: 2
# Categoria: Aerodynamics                                                                Livros: 2
# Categoria: Aerospace & Air Transport Industries                                        Livros: 1
# Categoria: Aerospace & Aviation Technology                                             Livros: 30
# Categoria: Afghan War                                                                  Livros: 5
# Categoria: African History                                                             Livros: 32
# Categoria: Age Groups                                                                  Livros: 2
# Categoria: Age Groups: Adolescents                                                     Livros: 6
# Categoria: Age Groups: Children                                                        Livros: 21
# Categoria: Age Groups: The Elderly                                                     Livros: 8
# Categoria: Agnosticism & Atheism                                                       Livros: 8
# Categoria: Agricultural Science                                                        Livros: 1
# Categoria: Agriculture & Farming                                                       Livros: 12
# Categoria: Agriculture & Related Industries                                            Livros: 5
# Categoria: Agronomy & Crop Production                                                  Livros: 2
# Categoria: Aid & Relief Programmes                                                     Livros: 1
# Categoria: Air Forces & Warfare                                                        Livros: 2
# Categoria: Air Sports & Recreations                                                    Livros: 15
# Categoria: Aircraft                                                                    Livros: 18
# Categoria: Alcoholic Beverages                                                         Livros: 24
# Categoria: Algebra                                                                     Livros: 18
# Categoria: Algebraic Geometry                                                          Livros: 2
# Categoria: Algorithms & Data Structures                                                Livros: 2
# Categoria: Alternative & Renewable Energy Sources & Technology                         Livros: 2
# Categoria: Alternative Belief Systems                                                  Livros: 15
# Categoria: Ambient & New Age Music                                                     Livros: 2
# Categoria: American Civil War                                                          Livros: 17
# Categoria: American Football                                                           Livros: 117
# Categoria: Amphibians                                                                  Livros: 3
# Categoria: Anaesthetics                                                                Livros: 2
# Categoria: Analytic Topology                                                           Livros: 1
# Categoria: Analytical & Jungian Psychology                                             Livros: 4
# Categoria: Analytical Chemistry                                                        Livros: 1
# Categoria: Analytical Philosophy & Logical Positivism                                  Livros: 3
# Categoria: Anarchism                                                                   Livros: 3
# Categoria: Anatomy                                                                     Livros: 21
# Categoria: Ancient Egyptian Religion & Mythology                                       Livros: 3
# Categoria: Ancient History: To C 500 CE                                                Livros: 181
# Categoria: Ancient Religions & Mythologies                                             Livros: 34
# Categoria: Anglican & Episcopalian Churches, Church Of England                         Livros: 18
# Categoria: Animal Behaviour                                                            Livros: 7
# Categoria: Animal Ecology                                                              Livros: 3
# Categoria: Animal Husbandry                                                            Livros: 8
# Categoria: Animal Pathology & Diseases                                                 Livros: 1
# Categoria: Animal Physiology                                                           Livros: 5
# Categoria: Animal Reproduction                                                         Livros: 1
# Categoria: Animal Stories                                                              Livros: 4
# Categoria: Animals & Nature In Art (still Life, Landscapes & Seascapes, Etc)           Livros: 7
# Categoria: Animals & Society                                                           Livros: 42
# Categoria: Animated Films                                                              Livros: 46
# Categoria: Anthologies                                                                 Livros: 1
# Categoria: Anthologies (non-poetry)                                                    Livros: 1335
# Categoria: Anthropology                                                                Livros: 88
# Categoria: Antiques & Collectables                                                     Livros: 38
# Categoria: Antiques & Collectables: Books, Manuscripts, Ephemera & Printed Matter      Livros: 17
# Categoria: Antiques & Collectables: Carpets, Rugs & Textiles                           Livros: 1
# Categoria: Antiques & Collectables: Ceramics & Glass                                   Livros: 1
# Categoria: Antiques & Collectables: Gold & Silver (other Than Jewellery)               Livros: 2
# Categoria: Antiques & Collectables: Pictures, Prints & Maps                            Livros: 7
# Categoria: Antiques & Collectables: Scientific & Musical Instruments                   Livros: 1
# Categoria: Antiques & Collectables: Toys, Games & Models                               Livros: 2
# Categoria: Apiculture (beekeeping)                                                     Livros: 2
# Categoria: Applied Ecology                                                             Livros: 31
# Categoria: Applied Linguistics For ELT                                                 Livros: 4
# Categoria: Applied Mathematics                                                         Livros: 47
# Categoria: Applied Optics                                                              Livros: 4
# Categoria: Applied Physics                                                             Livros: 3
# Categoria: Archaeological Methodology & Techniques                                     Livros: 3
# Categoria: Archaeology                                                                 Livros: 53
# Categoria: Archaeology By Period / Region                                              Livros: 5
# Categoria: Archery                                                                     Livros: 10
# Categoria: Architectural Structure & Design                                            Livros: 3
# Categoria: Architecture                                                                Livros: 15
# Categoria: Architecture: Professional Practice                                         Livros: 3
# Categoria: Armaments Industries                                                        Livros: 1
# Categoria: Armed Conflict                                                              Livros: 1
# Categoria: Arms Negotiation & Control                                                  Livros: 2
# Categoria: Art                                                                         Livros: 3
# Categoria: Art & Design                                                                Livros: 7
# Categoria: Art & Photography                                                           Livros: 15
# Categoria: Art Books                                                                   Livros: 108
# Categoria: Art Finance                                                                 Livros: 14
# Categoria: Art Forms                                                                   Livros: 3
# Categoria: Art History                                                                 Livros: 69
# Categoria: Art History: Ancient & Classical BCE to c 500 CE                            Livros: 4
# Categoria: Art History: Byzantine & Medieval c 500 CE to c 1400                        Livros: 4
# Categoria: Art History: From c 1960                                                    Livros: 54
# Categoria: Art History: Pre-History                                                    Livros: 4
# Categoria: Art History: Renaissance                                                    Livros: 4
# Categoria: Art History: c 1400 to c 1600                                               Livros: 1
# Categoria: Art History: c 1600 to c 1800                                               Livros: 2
# Categoria: Art History: c 1800 to c 1900                                               Livros: 3
# Categoria: Art History: c 1900 -                                                       Livros: 11
# Categoria: Art Techniques & Principles                                                 Livros: 15
# Categoria: Art Theory                                                                  Livros: 22
# Categoria: Art Treatments & Subjects                                                   Livros: 6
# Categoria: Artificial Intelligence                                                     Livros: 46
# Categoria: Asian History                                                               Livros: 127
# Categoria: Aspects Of Religion (non-Christian)                                         Livros: 15
# Categoria: Assertiveness, Motivation & Self-esteem                                     Livros: 70
# Categoria: Astral Projection & Out-of-body Experiences                                 Livros: 57
# Categoria: Astrology                                                                   Livros: 10
# Categoria: Astronautics                                                                Livros: 20
# Categoria: Astronomical Charts & Atlases                                               Livros: 2
# Categoria: Astronomical Observation: Observatories, Equipment & Methods                Livros: 5
# Categoria: Astronomy, Space & Time                                                     Livros: 154
# Categoria: Astrophysics                                                                Livros: 72
# Categoria: Atlases                                                                     Livros: 15
# Categoria: Atomic & Molecular Physics                                                  Livros: 21
# Categoria: Audio Processing                                                            Livros: 14
# Categoria: Audiology & Otology                                                         Livros: 2
# Categoria: Australasian & Pacific History                                              Livros: 23
# Categoria: Autobiography: Arts & Entertainment                                         Livros: 273
# Categoria: Autobiography: Business & Industry                                          Livros: 3
# Categoria: Autobiography: General                                                      Livros: 66
# Categoria: Autobiography: Historical, Political & Military                             Livros: 10
# Categoria: Autobiography: Literary                                                     Livros: 14
# Categoria: Autobiography: Science, Technology & Engineering                            Livros: 7
# Categoria: Autobiography: Sport                                                        Livros: 34
# Categoria: Automatic Control Engineering                                               Livros: 9
# Categoria: Automation Of Library & Information Processes                               Livros: 1
# Categoria: Automotive Technology & Trades                                              Livros: 8
# Categoria: Baby Names                                                                  Livros: 1
# Categoria: Bacteriology (non-medical)                                                  Livros: 2
# Categoria: Baha'i                                                                      Livros: 2
# Categoria: Ballet                                                                      Livros: 12
# Categoria: Ballroom Dancing                                                            Livros: 20
# Categoria: Banking                                                                     Livros: 2
# Categoria: Baptist Churches                                                            Livros: 4
# Categoria: Baroque Music (c 1600 To C 1750)                                            Livros: 4
# Categoria: Baseball                                                                    Livros: 131
# Categoria: Basketball                                                                  Livros: 83
# Categoria: Battles                                                                     Livros: 1
# Categoria: Battles & Campaigns                                                         Livros: 9
# Categoria: Beers                                                                       Livros: 16
# Categoria: Behavioural Theory (Behaviourism)                                           Livros: 10
# Categoria: Beverages                                                                   Livros: 10
# Categoria: Bible Readings, Selections & Meditations                                    Livros: 18
# Categoria: Bible Stories                                                               Livros: 3
# Categoria: Bible Studies: For Individual Or Small Group Study                          Livros: 13
# Categoria: Bibles                                                                      Livros: 49
# Categoria: Biblical Archaeology                                                        Livros: 3
# Categoria: Biblical Commentaries                                                       Livros: 43
# Categoria: Biblical Concordances                                                       Livros: 1
# Categoria: Biblical Exegesis & Hermeneutics                                            Livros: 26
# Categoria: Biblical Studies & Exegesis                                                 Livros: 279
# Categoria: Bibliographies, Catalogues, Discographies                                   Livros: 35
# Categoria: Bilingual & Multilingual Dictionaries                                       Livros: 15
# Categoria: Bilingualism & Multilingualism                                              Livros: 14
# Categoria: Bio-ethics                                                                  Livros: 16
# Categoria: Biochemical Engineering                                                     Livros: 4
# Categoria: Biochemical Immunology                                                      Livros: 1
# Categoria: Biochemistry                                                                Livros: 20
# Categoria: Biodiversity                                                                Livros: 5
# Categoria: Biogeography                                                                Livros: 7
# Categoria: Biography                                                                   Livros: 2
# Categoria: Biography: Arts & Entertainment                                             Livros: 534
# Categoria: Biography: Business & Industry                                              Livros: 18
# Categoria: Biography: General                                                          Livros: 647
# Categoria: Biography: Historical, Political & Military                                 Livros: 116
# Categoria: Biography: Literary                                                         Livros: 103
# Categoria: Biography: Religious & Spiritual                                            Livros: 83
# Categoria: Biography: Royalty                                                          Livros: 2
# Categoria: Biography: Science, Technology & Engineering                                Livros: 108
# Categoria: Biography: Sport                                                            Livros: 117
# Categoria: Biology                                                                     Livros: 4
# Categoria: Biology, Life Sciences                                                      Livros: 158
# Categoria: Biomedical Engineering                                                      Livros: 2
# Categoria: Biophysics                                                                  Livros: 9
# Categoria: Biotechnology                                                               Livros: 22
# Categoria: Biotechnology Industries                                                    Livros: 2
# Categoria: Birds (ornithology)                                                         Livros: 4
# Categoria: Birds, Including Cage Birds, As Pets                                        Livros: 9
# Categoria: Birth Control, Contraception, Family Planning                               Livros: 1
# Categoria: Black & Asian Studies                                                       Livros: 76
# Categoria: Blasphemy, Heresy, Apostasy                                                 Livros: 16
# Categoria: Blues                                                                       Livros: 2
# Categoria: Boating                                                                     Livros: 25
# Categoria: Body Art & Tattooing                                                        Livros: 3
# Categoria: Book & Paper Crafts                                                         Livros: 4
# Categoria: Botany & Plant Sciences                                                     Livros: 33
# Categoria: Bowls, Bowling, Petanque                                                    Livros: 2
# Categoria: Boxing                                                                      Livros: 3
# Categoria: British & Irish History                                                     Livros: 181
# Categoria: Buddhist Books                                                              Livros: 56
# Categoria: Buddhist Life & Practice                                                    Livros: 2
# Categoria: Buddhist Sacred Texts                                                       Livros: 6
# Categoria: Buddhist Worship, Rites & Ceremonies                                        Livros: 4
# Categoria: Budgeting & Financial Management                                            Livros: 9
# Categoria: Building Construction & Materials                                           Livros: 3
# Categoria: Bullying & Anti-bullying Strategies                                         Livros: 12
# Categoria: Buses, Trams & Commercial                                                   Livros: 1
# Categoria: Business & Management                                                       Livros: 70
# Categoria: Business Applications                                                       Livros: 25
# Categoria: Business Communication & Presentation                                       Livros: 18
# Categoria: Business Competition                                                        Livros: 2
# Categoria: Business Ethics                                                             Livros: 15
# Categoria: Business Innovation                                                         Livros: 3
# Categoria: Business Mathematics & Systems                                              Livros: 4
# Categoria: Business Negotiation                                                        Livros: 1
# Categoria: Business Strategy                                                           Livros: 20
# Categoria: Business Studies                                                            Livros: 3
# Categoria: Business Studies: General                                                   Livros: 47
# Categoria: Business, Finance & Law                                                     Livros: 2
# Categoria: Cakes, Baking, Icing & Sugarcraft                                           Livros: 8
# Categoria: Calculus                                                                    Livros: 3
# Categoria: Calculus & Mathematical Analysis                                            Livros: 7
# Categoria: Calvinist, Reformed & Presbyterian Churches                                 Livros: 7
# Categoria: Camping & Woodcraft                                                         Livros: 23
# Categoria: Canoeing & Kayaking                                                         Livros: 21
# Categoria: Capital Markets & Securities Law & Regulation                               Livros: 2
# Categoria: Car Racing                                                                  Livros: 2
# Categoria: Caravan & Camp-site Guides                                                  Livros: 18
# Categoria: Cardiothoracic Surgery                                                      Livros: 1
# Categoria: Cardiovascular Medicine                                                     Livros: 2
# Categoria: Care & Restoration Of Antiques                                              Livros: 3
# Categoria: Careers Guidance                                                            Livros: 44
# Categoria: Carpentry                                                                   Livros: 1
# Categoria: Cartography, Map-making & Projections                                       Livros: 26
# Categoria: Cartoons                                                                    Livros: 1
# Categoria: Cartoons & Comic Strips                                                     Livros: 23
# Categoria: Carving & Modelling, Moulding & Casting                                     Livros: 1
# Categoria: Cats As Pets                                                                Livros: 21
# Categoria: Causes & Prevention Of Crime                                                Livros: 2
# Categoria: Celebrity Biographies & Books                                               Livros: 39
# Categoria: Celebrity Chefs                                                             Livros: 6
# Categoria: Cellular Biology (cytology)                                                 Livros: 14
# Categoria: Cellular Physiology                                                         Livros: 1
# Categoria: Celtic Religion & Mythology                                                 Livros: 2
# Categoria: Central Government                                                          Livros: 10
# Categoria: Central Government Policies                                                 Livros: 52
# Categoria: Ceramics: Artworks                                                          Livros: 2
# Categoria: Chakras, Auras & Spiritual Energy                                           Livros: 13
# Categoria: Chaos Theory                                                                Livros: 4
# Categoria: Characters                                                                  Livros: 2
# Categoria: Charities, Voluntary Services & Philanthropy                                Livros: 5
# Categoria: Chemical & Biological Weapons                                               Livros: 1
# Categoria: Chemical Engineering                                                        Livros: 1
# Categoria: Chemistry Books                                                             Livros: 42
# Categoria: Child & Developmental Psychology                                            Livros: 34
# Categoria: Child Abuse                                                                 Livros: 3
# Categoria: Child Care & Upbringing                                                     Livros: 28
# Categoria: Child Welfare                                                               Livros: 1
# Categoria: Children's Books                                                            Livros: 1
# Categoria: Children's Buddhist Books                                                   Livros: 1
# Categoria: Children's Christian Books                                                  Livros: 3
# Categoria: Children's Fiction                                                          Livros: 12
# Categoria: Children's Foreign Language Books                                           Livros: 30
# Categoria: Children's Foreign Language Dictionaries                                    Livros: 1
# Categoria: Children's General Story Books                                              Livros: 4
# Categoria: Children's Geography Books                                                  Livros: 9
# Categoria: Children's Health Books                                                     Livros: 3
# Categoria: Children's Hobby & Gaming Books                                             Livros: 7
# Categoria: Children's Literature Studies: General                                      Livros: 25
# Categoria: Children's Music Books                                                      Livros: 1
# Categoria: Children's Reference Books                                                  Livros: 4
# Categoria: Children's Religious Books                                                  Livros: 1
# Categoria: Children's Sports Books                                                     Livros: 36
# Categoria: Children's Stationery                                                       Livros: 3
# Categoria: Chinese Medicine & Acupuncture                                              Livros: 1
# Categoria: Chiropody & Podiatry                                                        Livros: 1
# Categoria: Chiropractic & Osteopathy                                                   Livros: 1
# Categoria: Choral Music                                                                Livros: 2
# Categoria: Choreography                                                                Livros: 20
# Categoria: Christian & Quasi-Christian Cults & Sects                                   Livros: 4
# Categoria: Christian Aspects Of Sexuality, Gender & Relationships                      Livros: 17
# Categoria: Christian Books                                                             Livros: 492
# Categoria: Christian Churches & Denominations                                          Livros: 51
# Categoria: Christian Communities & Monasticism                                         Livros: 6
# Categoria: Christian Counselling                                                       Livros: 15
# Categoria: Christian Institutions & Organizations                                      Livros: 169
# Categoria: Christian Instruction                                                       Livros: 38
# Categoria: Christian Leaders & Leadership                                              Livros: 13
# Categoria: Christian Life & Practice                                                   Livros: 209
# Categoria: Christian Liturgy, Prayerbooks & Hymnals                                    Livros: 4
# Categoria: Christian Ministry & Pastoral Activity                                      Livros: 69
# Categoria: Christian Mission & Evangelism                                              Livros: 43
# Categoria: Christian Mysticism                                                         Livros: 6
# Categoria: Christian Prayer                                                            Livros: 2
# Categoria: Christian Prayerbooks                                                       Livros: 3
# Categoria: Christian Sacraments                                                        Livros: 9
# Categoria: Christian Sermons                                                           Livros: 14
# Categoria: Christian Social Thought & Activity                                         Livros: 66
# Categoria: Christian Spirituality & Religious Experience                               Livros: 52
# Categoria: Christian Theology                                                          Livros: 553
# Categoria: Christian Worship, Rites & Ceremonies                                       Livros: 37
# Categoria: Church History                                                              Livros: 54
# Categoria: Cinema Industry                                                             Livros: 4
# Categoria: Cinematography, Television Camerawork                                       Livros: 15
# Categoria: Circuits & Components                                                       Livros: 7
# Categoria: Circus                                                                      Livros: 4
# Categoria: Citizenship & Social Education                                              Livros: 27
# Categoria: City & Town Planning - Architectural Aspects                                Livros: 2
# Categoria: Civil Engineering, Surveying & Building                                     Livros: 6
# Categoria: Civil Procedure, Litigation & Dispute Resolution                            Livros: 2
# Categoria: Civil Rights & Citizenship                                                  Livros: 15
# Categoria: Civil Service & Public Sector                                               Livros: 3
# Categoria: Clairvoyance & Precognition                                                 Livros: 34
# Categoria: Classic Books & Novels                                                      Livros: 73
# Categoria: Classic Horror                                                              Livros: 4
# Categoria: Classic Travel Writing                                                      Livros: 13
# Categoria: Classical Greek & Roman Archaeology                                         Livros: 4
# Categoria: Classical History / Classical Civilisation                                  Livros: 128
# Categoria: Classical Mechanics                                                         Livros: 15
# Categoria: Climbing & Mountaineering                                                   Livros: 14
# Categoria: Clinical & Internal Medicine                                                Livros: 3
# Categoria: Clinical Psychology                                                         Livros: 13
# Categoria: Clocks, Chronometers & Watches (horology)                                   Livros: 1
# Categoria: Coding Theory & Cryptology                                                  Livros: 2
# Categoria: Cognition & Cognitive Psychology                                            Livros: 102
# Categoria: Cognitivism, Cognitive Theory                                               Livros: 5
# Categoria: Coins, Banknotes, Medals, Seals (numismatics)                               Livros: 1
# Categoria: Cold War                                                                    Livros: 6
# Categoria: Colleges Of Further Education                                               Livros: 2
# Categoria: Colleges Of Higher Education                                                Livros: 4
# Categoria: Colonialism & Imperialism                                                   Livros: 14
# Categoria: Combat / Defence Skills & Manuals                                           Livros: 1
# Categoria: Combat Sports & Self-defence                                                Livros: 22
# Categoria: Combinatorics & Graph Theory                                                Livros: 4
# Categoria: Comic Book & Cartoon Art                                                    Livros: 16
# Categoria: Commercial Law                                                              Livros: 1
# Categoria: Communication Studies                                                       Livros: 294
# Categoria: Communications Engineering / Telecommunications                             Livros: 38
# Categoria: Community Nursing                                                           Livros: 1
# Categoria: Comparative Law                                                             Livros: 2
# Categoria: Comparative Politics                                                        Livros: 15
# Categoria: Comparative Religion                                                        Livros: 225
# Categoria: Compilers                                                                   Livros: 3
# Categoria: Complementary Medicine                                                      Livros: 7
# Categoria: Complementary Therapies, Healing & Health                                   Livros: 44
# Categoria: Complex Analysis, Complex Variables                                         Livros: 2
# Categoria: Computational Linguistics                                                   Livros: 20
# Categoria: Computer Architecture & Logic Design                                        Livros: 4
# Categoria: Computer Games Design                                                       Livros: 1
# Categoria: Computer Hardware                                                           Livros: 2
# Categoria: Computer Networking & Communications                                        Livros: 8
# Categoria: Computer Programming / Software Development                                 Livros: 9
# Categoria: Computer Science                                                            Livros: 44
# Categoria: Computer Security                                                           Livros: 1
# Categoria: Computer Vision                                                             Livros: 1
# Categoria: Computer-aided Design (CAD)                                                 Livros: 3
# Categoria: Computing                                                                   Livros: 2
# Categoria: Computing: General                                                          Livros: 59
# Categoria: Concert Halls, Arenas, Stadia                                               Livros: 3
# Categoria: Condensed Matter Physics (liquid State & Solid State Physics)               Livros: 5
# Categoria: Confucianism                                                                Livros: 6
# Categoria: Conjuring & Magic                                                           Livros: 8
# Categoria: Conservation Of The Environment                                             Livros: 67
# Categoria: Conservation Of Wildlife & Habitats                                         Livros: 28
# Categoria: Conservatism & Right-of-centre Democratic Ideologies                        Livros: 16
# Categoria: Conspiracy Theories                                                         Livros: 12
# Categoria: Constitution: Government & The State                                        Livros: 19
# Categoria: Constitutional & Administrative Law                                         Livros: 10
# Categoria: Consultancy & Grants For Businesses                                         Livros: 1
# Categoria: Consumer Advice                                                             Livros: 2
# Categoria: Consumerism                                                                 Livros: 5
# Categoria: Contemporary Dance                                                          Livros: 8
# Categoria: Contemporary Fiction                                                        Livros: 195
# Categoria: Contemporary Non-Christian & Para-Christian Cults & Sects                   Livros: 17
# Categoria: Contract Law                                                                Livros: 3
# Categoria: Cookery By Ingredient                                                       Livros: 8
# Categoria: Cookery Dishes & Courses                                                    Livros: 11
# Categoria: Cookery For Dietary Conditions                                              Livros: 1
# Categoria: Cooking For Parties                                                         Livros: 1
# Categoria: Cooking With Meat & Game                                                    Livros: 2
# Categoria: Coping With Death & Bereavement                                             Livros: 28
# Categoria: Coping With Disability                                                      Livros: 6
# Categoria: Coping With Drug & Alcohol Abuse                                            Livros: 8
# Categoria: Coping With Eating Disorders                                                Livros: 3
# Categoria: Coping With Illness                                                         Livros: 13
# Categoria: Coping With Old Age                                                         Livros: 5
# Categoria: Coping With Personal Problems                                               Livros: 9
# Categoria: Coping With Stress                                                          Livros: 5
# Categoria: Copyright Law                                                               Livros: 1
# Categoria: Corporate Governance & Responsibilities                                     Livros: 2
# Categoria: Cosmetics Technology                                                        Livros: 1
# Categoria: Cosmetics, Hair & Beauty                                                    Livros: 9
# Categoria: Cosmology & The Universe                                                    Livros: 65
# Categoria: Counselling & Advice Services                                               Livros: 5
# Categoria: Country & Western Music                                                     Livros: 4
# Categoria: Countryside, Country Life                                                   Livros: 5
# Categoria: Courts & Procedure                                                          Livros: 5
# Categoria: Crafts & Hobbies                                                            Livros: 47
# Categoria: Creative Therapy (eg Art, Music, Drama)                                     Livros: 3
# Categoria: Creative Writing & Creative Writing Guides                                  Livros: 181
# Categoria: Cricket                                                                     Livros: 13
# Categoria: Crime                                                                       Livros: 15
# Categoria: Crime & Criminology                                                         Livros: 40
# Categoria: Crime Fiction                                                               Livros: 15
# Categoria: Crimean War                                                                 Livros: 2
# Categoria: Criminal Investigation & Detection                                          Livros: 2
# Categoria: Criminal Justice Law                                                        Livros: 1
# Categoria: Criminal Law & Procedure                                                    Livros: 12
# Categoria: Criminal Or Forensic Psychology                                             Livros: 1
# Categoria: Criticism & Exegesis Of Sacred Texts                                        Livros: 4
# Categoria: Cruises                                                                     Livros: 19
# Categoria: Crusades                                                                    Livros: 4
# Categoria: Cryogenics                                                                  Livros: 1
# Categoria: Crystallography                                                             Livros: 2
# Categoria: Cultural Studies                                                            Livros: 177
# Categoria: Curriculum Planning & Development                                           Livros: 232
# Categoria: Cybernetics & Systems Theory                                                Livros: 19
# Categoria: Cycling                                                                     Livros: 55
# Categoria: Cycling, Boarding & Skating (Children's/YA)                                 Livros: 1
# Categoria: DIY: Carpentry & Woodworking                                                Livros: 2
# Categoria: DIY: General                                                                Livros: 14
# Categoria: DIY: House Maintenance Manuals                                              Livros: 2
# Categoria: DNA & Genome                                                                Livros: 4
# Categoria: Dance                                                                       Livros: 152
# Categoria: Dance & Other Performing Arts                                               Livros: 516
# Categoria: Data Analysis: General                                                      Livros: 4
# Categoria: Data Capture & Analysis                                                     Livros: 2
# Categoria: Data Mining                                                                 Livros: 1
# Categoria: Data Warehousing                                                            Livros: 1
# Categoria: Databases                                                                   Livros: 3
# Categoria: Dating, Relationships, Living Together & Marriage                           Livros: 24
# Categoria: Death & Bereavement                                                         Livros: 2
# Categoria: Decision Theory: General                                                    Livros: 5
# Categoria: Deconstructionism, Structuralism, Post-structuralism                        Livros: 12
# Categoria: Decorative Arts                                                             Livros: 1
# Categoria: Decorative Wood & Metalwork                                                 Livros: 1
# Categoria: Defence Strategy, Planning & Research                                       Livros: 2
# Categoria: Demonstrations & Protest Movements                                          Livros: 3
# Categoria: Dentistry                                                                   Livros: 3
# Categoria: Desktop Publishing                                                          Livros: 2
# Categoria: Desserts                                                                    Livros: 4
# Categoria: Development Economics                                                       Livros: 32
# Categoria: Development Studies                                                         Livros: 10
# Categoria: Developmental Biology                                                       Livros: 12
# Categoria: Dialect, Slang & Jargon                                                     Livros: 9
# Categoria: Diaries, Letters & Journals                                                 Livros: 69
# Categoria: Dictionaries & Dictionary Books                                             Livros: 90
# Categoria: Dictionaries & Languages                                                    Livros: 12
# Categoria: Dictionaries Of Biography (Who's Who)                                       Livros: 10
# Categoria: Dictionaries Of Quotations                                                  Livros: 18
# Categoria: Dictionaries for Kids                                                       Livros: 2
# Categoria: Dietetics & Nutrition                                                       Livros: 4
# Categoria: Diets & Dieting                                                             Livros: 10
# Categoria: Differential Calculus & Equations                                           Livros: 7
# Categoria: Digital Animation                                                           Livros: 1
# Categoria: Digital Lifestyle                                                           Livros: 9
# Categoria: Digital Music: Consumer/user Guides                                         Livros: 1
# Categoria: Digital TV & Media Centres: Consumer/user Guides                            Livros: 10
# Categoria: Digital Video: Professional                                                 Livros: 1
# Categoria: Dinosaurs                                                                   Livros: 2
# Categoria: Dinosaurs & The Prehistoric World                                           Livros: 6
# Categoria: Diplomacy                                                                   Livros: 4
# Categoria: Directories                                                                 Livros: 13
# Categoria: Disability                                                                  Livros: 3
# Categoria: Disability: Social Aspects                                                  Livros: 11
# Categoria: Discrete Mathematics                                                        Livros: 5
# Categoria: Diseases & Disorders                                                        Livros: 11
# Categoria: Distributive Industries                                                     Livros: 5
# Categoria: Doctor/patient Relationship                                                 Livros: 2
# Categoria: Documentary Films                                                           Livros: 8
# Categoria: Dog Obedience & Training                                                    Livros: 5
# Categoria: Dogs As Pets                                                                Livros: 61
# Categoria: Domestic Animals & Pets                                                     Livros: 29
# Categoria: Domestic Trade                                                              Livros: 4
# Categoria: Domestic Violence                                                           Livros: 1
# Categoria: Drama                                                                       Livros: 13
# Categoria: Drawing                                                                     Livros: 8
# Categoria: Dreams & Their Interpretation                                               Livros: 28
# Categoria: Drought & Water Supply                                                      Livros: 1
# ...
# Categoria: Teaching Of Autistic Students                                               Livros: 2
# Categoria: Teaching Of Dyslexic Students                                               Livros: 4
# Categoria: Teaching Of Gifted Students                                                 Livros: 22
# Categoria: Teaching Of Physically Disabled Students                                    Livros: 12
# Categoria: Teaching Of Specific Groups & Persons With Special Educational Needs        Livros: 184
# Categoria: Teaching Of Students With Emotional & Behavioural Difficulties              Livros: 32
# Categoria: Teaching Of Students With English As A Second Language (TESOL)              Livros: 120
# Categoria: Teaching Of Students With Specific Learning Difficulties / Needs            Livros: 44
# Categoria: Teaching Resources & Education                                              Livros: 1110
# Categoria: Teaching Skills & Techniques                                                Livros: 4122
# Categoria: Teaching Staff                                                              Livros: 390
# Categoria: Teams & Clubs                                                               Livros: 7
# Categoria: Technical Design                                                            Livros: 10
# Categoria: Technical Writing                                                           Livros: 11
# Categoria: Techniques Of Music / Music Tutorials                                       Livros: 82
# Categoria: Technology                                                                  Livros: 8
# Categoria: Technology & Engineering                                                    Livros: 2
# Categoria: Technology: General Issues                                                  Livros: 68
# Categoria: Teenagers: Advice For Parents                                               Livros: 4
# Categoria: Television                                                                  Livros: 4450
# Categoria: Television & Film                                                           Livros: 22
# Categoria: Television Production: Technical & Background Skills                        Livros: 40
# Categoria: Television Scripts & Screenplays                                            Livros: 154
# Categoria: Television Soap Operas                                                      Livros: 18
# Categoria: Television Technology                                                       Livros: 52
# Categoria: Tennis                                                                      Livros: 4
# Categoria: Terminal Care Nursing                                                       Livros: 3
# Categoria: Terrorism, Armed Struggle                                                   Livros: 36
# Categoria: Terrorist Attack                                                            Livros: 1
# Categoria: Testing Of Materials                                                        Livros: 3
# Categoria: Textile Design & Theory                                                     Livros: 6
# Categoria: The Environment                                                             Livros: 1
# Categoria: Theatre Direction & Production                                              Livros: 88
# Categoria: Theatre Management                                                          Livros: 5
# Categoria: Theatre Studies                                                             Livros: 1854
# Categoria: Theatre: Individual Actors & Directors                                      Livros: 30
# Categoria: Theatre: Technical & Background Skills                                      Livros: 38
# Categoria: Theology                                                                    Livros: 174
# Categoria: Theoretical & Mathematical Astronomy                                        Livros: 4
# Categoria: Theory Of Architecture                                                      Livros: 1
# Categoria: Theory Of Music & Musicology                                                Livros: 28
# Categoria: Theory Of Warfare & Military Science                                        Livros: 2
# Categoria: Theosophy & Anthroposophy                                                   Livros: 23
# Categoria: Therapy & Therapeutics                                                      Livros: 2
# Categoria: Thermodynamics & Heat                                                       Livros: 2
# Categoria: Thesauri                                                                    Livros: 3
# Categoria: Thriller Books                                                              Livros: 14
# Categoria: Thriller Books for Children                                                 Livros: 1
# Categoria: Thrillers                                                                   Livros: 14
# Categoria: Tibetan Buddhism                                                            Livros: 16
# Categoria: Time (chronology), Time Systems & Standards                                 Livros: 20
# Categoria: Time Management                                                             Livros: 6
# Categoria: Tips & Advice                                                               Livros: 78
# Categoria: Tomography                                                                  Livros: 1
# Categoria: Topology                                                                    Livros: 2
# Categoria: Tourism Industry                                                            Livros: 5
# Categoria: Toys: Making & Decorating                                                   Livros: 3
# Categoria: Track & Field Sports, Athletics                                             Livros: 33
# Categoria: Trade Agreements                                                            Livros: 2
# Categoria: Traditional                                                                 Livros: 4
# Categoria: Traditional Medicine & Herbal Remedies                                      Livros: 2
# Categoria: Training & Coaching                                                         Livros: 32
# Categoria: Trains & Railways                                                           Livros: 5
# Categoria: Transistors                                                                 Livros: 1
# Categoria: Translation & Interpretation                                                Livros: 25
# Categoria: Transport Industries                                                        Livros: 3
# Categoria: Transport Planning & Policy                                                 Livros: 1
# Categoria: Transport Technology & Trades                                               Livros: 1
# Categoria: Transportation Books                                                        Livros: 10
# Categoria: Transportation Books for Children                                           Livros: 1
# Categoria: Travel & Holiday Guides                                                     Livros: 31
# Categoria: Travel Maps                                                                 Livros: 248
# Categoria: Travel Maps & Atlases                                                       Livros: 358
# Categoria: Travel With Children / Family Holidays                                      Livros: 2
# Categoria: Travel Writing                                                              Livros: 88
# Categoria: Trees, Wildflowers & Plants                                                 Livros: 71
# Categoria: Tribal Religions                                                            Livros: 13
# Categoria: Trigonometry                                                                Livros: 1
# Categoria: True Crime Biographies                                                      Livros: 45
# Categoria: True Crime Books                                                            Livros: 45
# Categoria: True Stories Of Heroism, Endurance & Survival                               Livros: 3
# Categoria: True Story Books                                                            Livros: 9
# Categoria: Typography & Lettering                                                      Livros: 1
# Categoria: UFOs & Extraterrestrial Beings                                              Livros: 371
# Categoria: UFOs & Extraterrestrial Beings (Children's/YA)                              Livros: 4
# Categoria: Unexplained Phenomena / The Paranormal                                      Livros: 1776
# Categoria: Universities                                                                Livros: 18
# Categoria: Urban & Municipal Planning                                                  Livros: 5
# Categoria: Urban Communities                                                           Livros: 28
# Categoria: Urology & Urogenital Medicine                                               Livros: 1
# Categoria: Usage & Grammar Guides                                                      Livros: 1862
# Categoria: User Interface Design & Usability                                           Livros: 4
# Categoria: Variety Shows, Music Hall, Cabaret                                          Livros: 16
# Categoria: Vegetarian Cookery                                                          Livros: 4
# Categoria: Verse                                                                       Livros: 1
# Categoria: Veterinary Medicine                                                         Livros: 2
# Categoria: Veterinary Medicine: Laboratory Animals                                     Livros: 1
# Categoria: Veterinary Medicine: Large Animals (domestic / Farm)                        Livros: 1
# Categoria: Veterinary Medicine: Small Animals (pets)                                   Livros: 2
# Categoria: Veterinary Radiology                                                        Livros: 1
# Categoria: Video Photography                                                           Livros: 7
# Categoria: Vietnam War                                                                 Livros: 5
# Categoria: Vintage Crime                                                               Livros: 2
# Categoria: Violence In Society                                                         Livros: 34
# Categoria: Virology (non-medical)                                                      Livros: 1
# Categoria: Virtual Reality                                                             Livros: 1
# Categoria: Viticulture                                                                 Livros: 1
# Categoria: Volcanology & Seismology                                                    Livros: 3
# Categoria: Volleyball                                                                  Livros: 47
# Categoria: WAP (wireless) Technology                                                   Livros: 3
# Categoria: Walking, Hiking, Trekking                                                   Livros: 50
# Categoria: War & Defence Operations                                                    Livros: 2
# Categoria: War Crimes                                                                  Livros: 2
# Categoria: Warfare & Defence                                                           Livros: 14
# Categoria: Water Sports & Recreations                                                  Livros: 8
# Categoria: Watercolours                                                                Livros: 1
# Categoria: Wave Mechanics (vibration & Acoustics)                                      Livros: 10
# Categoria: Weather                                                                     Livros: 6
# Categoria: Web Graphics & Design                                                       Livros: 1
# Categoria: Web Programming                                                             Livros: 2
# Categoria: Weddings, Wedding Planners                                                  Livros: 2
# Categoria: Welding                                                                     Livros: 2
# Categoria: Welfare & Benefit Systems                                                   Livros: 1
# Categoria: Welfare Economics                                                           Livros: 2
# Categoria: Western Classical Music                                                     Livros: 14
# Categoria: Western Philosophy, From C 1900 -                                           Livros: 125
# Categoria: Western Philosophy: Ancient, To C 500                                       Livros: 62
# Categoria: Western Philosophy: C 1600 To C 1900                                        Livros: 22
# Categoria: Western Philosophy: Enlightenment                                           Livros: 1
# Categoria: Western Philosophy: Medieval & Renaissance, C 500 To C 1600                 Livros: 63
# Categoria: Westerns                                                                    Livros: 1
# Categoria: Wildlife                                                                    Livros: 2
# Categoria: Wildlife: Aquatic Creatures                                                 Livros: 31
# Categoria: Wildlife: Birds & Birdwatching                                              Livros: 47
# Categoria: Wildlife: Butterflies, Other Insects & Spiders                              Livros: 41
# Categoria: Wildlife: General Interest                                                  Livros: 77
# Categoria: Wildlife: Mammals                                                           Livros: 52
# Categoria: Wildlife: Reptiles & Amphibians                                             Livros: 31
# Categoria: Wind Instruments                                                            Livros: 2
# Categoria: Winemaking Technology                                                       Livros: 1
# Categoria: Wines                                                                       Livros: 4
# Categoria: Winter Sports                                                               Livros: 216
# Categoria: Witchcraft                                                                  Livros: 3
# Categoria: Witchcraft & Wicca                                                          Livros: 49
# Categoria: Witches & Ghosts (Children's/YA)                                            Livros: 1
# Categoria: Women's Health                                                              Livros: 4
# Categoria: Work                                                                        Livros: 4
# Categoria: World Atlases / World Maps                                                  Livros: 3792
# Categoria: World War 1 Books                                                           Livros: 14
# Categoria: World War 1 Fiction                                                         Livros: 1
# Categoria: World War 2 Books                                                           Livros: 32
# Categoria: Worship, Rites & Ceremonies                                                 Livros: 10
# Categoria: Wrestling                                                                   Livros: 7
# Categoria: Writing & Editing Guides                                                    Livros: 63
# Categoria: Writing Skills                                                              Livros: 18
# Categoria: Writing Systems, Alphabets                                                  Livros: 28
# Categoria: Yearbooks, Annuals, Almanacs                                                Livros: 29
# Categoria: Zen Buddhism                                                                Livros: 13
# Categoria: Zoology & Animal Sciences                                                   Livros: 50
# Categoria: Zoology: Invertebrates                                                      Livros: 3
# Categoria: Zoology: Mammals                                                            Livros: 8
# Categoria: Zoos & Wildlife Parks                                                       Livros: 1
# Categoria: Zoroastrianism                                                              Livros: 3

# %%
# Questão 5:
print('Top 5 categorias com maiores quantidades de livros:\n')
for ix, row in enumerate(ranked_category.values):
    print('{}° categoria: {} com {} livros'.format(ix+1, row[0], row[1]))
# Out:
# Top 5 categorias com maiores quantidades de livros:
#
# 1° categoria: Television com 4450 livros
# 2° categoria: Teaching Skills & Techniques com 4122 livros
# 3° categoria: World Atlases / World Maps com 3792 livros
# 4° categoria: Usage & Grammar Guides com 1862 livros
# 5° categoria: Theatre Studies com 1854 livros

# %%
# Questão 6:
print('Formato mais utilizado: {} com {} utilizações'.format(most_used_format, quantity_format))
# Out:
# Formato mais utilizado: Paperback com 13497 utilizações

# %%
# Questão 7:
print('Livros mais bem posicionados relativos a bestseller:\n')
for row in ranked_bestseller.values:
    print('Livro: "{}" na posição {}'.format(row[0], row[1]))
# Out:
# Livros mais bem posicionados relativos a bestseller:
#
# Livro: "We" na posição 2038.0
# Livro: "Mushrooms" na posição 5718.0
# Livro: "Enlightenment Now : The Case for Reason, Science, Humanism, and Progress" na posição 11401.0
# Livro: "Affective Dimensions in Chemistry Education" na posição 12512.0
# Livro: "The Science Delusion : Freeing the Spirit of Enquiry (NEW EDITION)" na posição 14602.0
# Livro: "The Age of Surveillance Capitalism : The Fight for a Human Future at the New Frontier of Power: Barack Obama's Books of 2019" na posição 14656.0
# Livro: "Quirkology : The Curious Science Of Everyday Lives" na posição 14804.0
# Livro: "Quiet : The power of introverts in a world that can't stop talking" na posição 14986.0
# Livro: "The Brain's Way of Healing : Stories of Remarkable Recoveries and Discoveries" na posição 15844.0
# Livro: "Enlightenment Now" na posição 16270.0

# %%
# Questão 8:
print('Livros mais bem posicionados relativos a média de nota:\n')
for row in ranked_rating.values:
    print('Livro: "{}" com nota {}'.format(row[0], row[1]))
# Out:
# Livros mais bem posicionados relativos a média de nota:
#
# Livro: "The Oxford Handbook of Early Christian Archaeology" com nota 5.0
# Livro: "Edward Albee : A Research and Production Sourcebook" com nota 5.0
# Livro: "Asia Classic, Tubed : Wall Maps Continents" com nota 5.0
# Livro: "Hauntingly Familiar : A Paranormal Thriller" com nota 5.0
# Livro: "The Other Judaisms of Late Antiquity : Second Edition" com nota 5.0
# Livro: "Freaky Florida : The Wonderhouse, the Devil's Tree, the Shaman of Philippe Park, and More" com nota 5.0
# Livro: "Families, Rabbis, and Education : Traditional Jewish Society in Nineteenth-century Eastern Europe" com nota 5.0
# Livro: "Total Transformation : Seven Sacred Steps to Freedom" com nota 5.0
# Livro: "Strategies for the Tech-Savvy Classroom" com nota 5.0
# Livro: "Spirals of Love : A Journey Into the Abyss of the Heartspace" com nota 5.0

# %%
# Questão 9:
print('{} livros possuem nota maior que 3,5'.format(best_ratings))
# Out:
# 8182 livros possuem nota maior que 3,5

# %%
# Questão 10:
print('{} livros foram publicados após 01-01-2020'.format(books_new_decade))
# Out:
# 1178 livros foram publicados após 01-01-2020

# %% [markdown]
# # Criação dos arquivos de saída

# %%
# Arquivo dataset com junções
df.to_csv('./resolucao/dataset_unificado.csv', index=False)

# Arquivo questão 4
total_category.to_csv('./resolucao/questao_4.csv', index=False, sep=';')

# Arquivo questões 1 a 3 e 5 a 10
with open('./resolucao/solucoes.txt', 'w') as outfile:
    outfile.write('>> Questão 1:\n')
    outfile.write('Há {} livros no dataset\n\n'.format(df.title.count()))
    
    outfile.write('>> Questão 2:\n')
    outfile.write('Há {} livros com apenas 1 autor\n\n'.format(df[df['author_quantity'] == 1].title.count()))
    
    outfile.write('>> Questão 3:\n')
    outfile.write('Top 5 autores com maiores quantidades de livros:\n')
    for ix, row in enumerate(ranked_authors.values):
        outfile.write('{}° autor: "{}" com {} livros\n'.format(ix+1, row[0], row[1]))
    
    
    outfile.write('\n>> Questão 5:\n')
    outfile.write('Top 5 categorias com maiores quantidades de livros:\n')
    for ix, row in enumerate(ranked_category.values):
        outfile.write('{}° categoria: "{}" com {} livros\n'.format(ix+1, row[0], row[1]))
    
    outfile.write('\n>> Questão 6:\n')
    outfile.write('Formato mais utilizado: "{}" com {} utilizações\n\n'.format(most_used_format, quantity_format))
    
    outfile.write('>> Questão 7:\n')
    outfile.write('Livros mais bem posicionados relativos a bestseller:\n')
    for row in ranked_bestseller.values:
        outfile.write('Livro: "{}" na posição {}\n'.format(row[0], row[1]))
        
    outfile.write('\n>> Questão 8:\n')
    outfile.write('Livros mais bem posicionados relativos à média de nota:\n')
    for row in ranked_rating.values:
        outfile.write('Livro: "{}" com nota {}\n'.format(row[0], row[1]))
    
    
    outfile.write('\n>> Questão 9:\n')
    outfile.write('{} livros possuem nota maior que 3,5\n\n'.format(best_ratings))
    
    outfile.write('>> Questão 10:\n')
    outfile.write('{} livros foram publicados após "01-01-2020"'.format(books_new_decade))
